# %% [markdown]
# # Mandy <3
#
# Places you should take a tumble down the mandelbrot:

# %%
import mandybrot as mandy

# %% [markdown]
# Settings:

# %%
WIDTH = 1920
HEIGHT = 1080
MAX_ITERS = 100
SCALE = 1e-7

# %% [markdown]
# Locations:

# %%
real = 0.42884
imag = -0.231345

data = mandy.sample.area(real, imag, WIDTH, HEIGHT, SCALE, MAX_ITERS)
cols = mandy.colour.image(data, MAX_ITERS, mandy.colour.jet_map)
mandy.colour.encode(cols)
# Out:
# 100%|█████████████████████████████| 2073600/2073600 [00:10<00:00, 197949.00it/s]
# <PIL.Image.Image image mode=RGB size=1920x1080>

# %%
real = 0.014567453577
imag = 0.847927409853

data = mandy.sample.area(real, imag, WIDTH, HEIGHT, SCALE, MAX_ITERS)
cols = mandy.colour.image(data, MAX_ITERS, mandy.colour.jet_map)
mandy.colour.encode(cols)
# Out:
# 100%|█████████████████████████████| 2073600/2073600 [00:17<00:00, 119736.94it/s]
# <PIL.Image.Image image mode=RGB size=1920x1080>

# %%
real = 0.019339021787
imag = 0.759651991342

data = mandy.sample.area(real, imag, WIDTH, HEIGHT, SCALE, MAX_ITERS)
cols = mandy.colour.image(data, MAX_ITERS, mandy.colour.jet_map)
mandy.colour.encode(cols)
# Out:
# 100%|█████████████████████████████| 2073600/2073600 [00:09<00:00, 229260.39it/s]
# <PIL.Image.Image image mode=RGB size=1920x1080>
